# %%
import urllib2
import requests

print('Beginning file download with requests')

states = ["al", "ak", "az", "ar", "ca", "co", "ct", "dc", "de", "fl", "ga", 
          "hi", "id", "il", "in", "ia", "ks", "ky", "la", "me", "md", 
          "ma", "mi", "mn", "ms", "mo", "mt", "ne", "nv", "nh", "nj", 
          "nm", "ny", "nc", "nd", "oh", "ok", "or", "pa", "ri", "sc", 
          "sd", "tn", "tx", "ut", "vt", "va", "wa", "wv", "wi", "wy"]

for state in states:
    for year in range (1997, 2018):
        url = 'https://www2.census.gov/programs-surveys/saipe/datasets/'
        url += str(year) + '/' + str(year) + '-state-and-county/est' + str(year)[-2:] + '-' + state + '.dat'  
        r = requests.get(url)
        savePath = 'Project/income_data/' + str(year) + '-' + state + '.csv'
        with open(savePath, 'wb') as f:  
            f.write(r.content)
print("Done downloading")
# Out:
# Beginning file download with requests
# Done downloading

# %%
import urllib2
import requests
columnIndex = ['FIPS State Code', 'FIPS County Code', 'All Ages Poverty', 
               '90% Lower Bound All Ages', 
               '90% Upper Bound All Ages',
               'Percent All Ages',
               '90% Lower Bound Percent',
               '90% Upper Bound Percent',
               '0-17', 
               '90% Lower Bound 0-17', 
               '90% Upper Bound 0-17', 
               'Percent 0-17',
               '90% Lower Bound Percent 0-17',
               '90% Upper Bound Percent 0-17', 
               '5-17',
               '90% Lower Bound 5-17',
               '90% Upper Bound 5-17',
               'Percent 5-17',
               '90% Lower Bound Percent 5-17',
               '90% Upper Bound Percent 5-17',
               'MedianHouseholdIncome', 
               '90% Lower Bound Median Household Income',
               '90% Upper Bound Median Household Income', 'County', 'Class', 'State']

states = ["al", "ak", "az", "ar", "ca", "co", "ct", "dc", "de", "fl", "ga", 
          "hi", "id", "il", "in", "ia", "ks", "ky", "la", "me", "md", 
          "ma", "mi", "mn", "ms", "mo", "mt", "ne", "nv", "nh", "nj", 
          "nm", "ny", "nc", "nd", "oh", "ok", "or", "pa", "ri", "sc", 
          "sd", "tn", "tx", "ut", "vt", "va", "wa", "wv", "wi", "wy"]

# %%
import pandas as pd

incomeDictionary = dict()

for year in range (2010, 2011):
    dataFrames = dict()
    for state in states:
        path = 'Project/income_data/' + str(year) + '-' + state + '.csv'
        data = pd.read_csv(path, delim_whitespace=True, header=0)
        data = data.drop(list(data)[-4:], axis=1)
        data = data.drop(list(data)[-1:], axis=1)
        if len(data.columns) > 26:
            data = data.drop(list(data)[26 - len(data.columns):], axis=1)
        data
        data.columns = columnIndex
        data.insert(0, "County Code", data['FIPS State Code']*1000 + data['FIPS County Code'] , True) 
        data = data.drop(list(data)[1], axis=1)
        data = data.drop(list(data)[1], axis=1)
        #data = data.drop(columns=['All Ages Poverty', '90% Lower Bound All Ages', '90% Upper Bound All Ages',
                         #'0-17', '90% Lower Bound 0-17', '90% Upper Bound 0-17', 
                          #'5-17','90% Lower Bound 5-17','90% Upper Bound 5-17'])
        data = data[['County Code','MedianHouseholdIncome']]
        dataFrames[state] = data
    incomeDictionary[year] = dataFrames

# %%
perYear = dict()
for year in range (2001, 2002):
    yearData = pd.DataFrame(columns=['County Code', 'MedianHouseholdIncome'])
    for state in states:
        yearData = yearData.append(incomeDictionary[year][state])
    perYear[year] = yearData
# Out:
# KeyErrorTraceback (most recent call last)
# <ipython-input-6-4f0043506ec9> in <module>()
#       3     yearData = pd.DataFrame(columns=['County Code', 'MedianHouseholdIncome'])
#       4     for state in states:
# ----> 5         yearData = yearData.append(incomeDictionary[year][state])
#       6     perYear[year] = yearData
#
# KeyError: 2001

# %%
import numpy as np
AQIDictionary = {}
start_year = 2000
YEARS = [start_year+i for i in range(18)]
for year in YEARS:
    df = pd.read_csv('Project/AQI_data/conreport' + str(year) + '.csv')
    df = df.drop(list(df)[2], axis=1)
    df = df.drop(list(df)[3], axis=1)
    df = df.drop(list(df)[4], axis=1)
    df = df.drop(list(df)[5], axis=1)
    df = df.drop(list(df)[6], axis=1)
    df = df.drop(list(df)[6], axis=1)
    df = df.drop(list(df)[7], axis=1)
    df = df.drop(list(df)[-1:], axis=1)
    df = df.replace('.', np.nan)
    df = df.dropna(thresh=6)
    AQIDictionary[year] = df

# %%
import pandas as pd
pop_density = pd.read_csv('Project/pop_density_data/pop_density_2010.csv')
pop_density = pop_density.set_index('County Code')
pop_density
# Out:
#              Population Density  Housing Density
# County Code
# 1001                       91.8             37.2
# 1003                      114.6             65.5
# 1005                       31.0             13.4
# 1007                       36.8             14.4
# 1009                       88.9             37.0
# 1011                       17.5              7.2
# 1013                       27.0             12.8
# 1015                      195.7             88.0
# 1017                       57.4             28.5
# 1019                       46.9             29.4
# 1021                       63.0             27.8
# 1023                       15.2              8.0
# 1025                       20.9             10.2
# 1027                       23.1             11.2
# 1029                       26.7             12.0
# 1031                       73.6             32.9
# 1033                       91.8             43.5
# 1035                       15.6              8.3
# 1037                       17.7             10.0
# 1039                       36.6             18.3
# 1041                       22.8             11.1
# 1043                      109.4             50.4
# 1045                       89.6             40.4
# 1047                       44.8             20.6
# 1049                       91.5             40.0
# 1051                      128.2             52.8
# 1053                       40.5             17.4
# 1055                      195.2             88.7
# 1057                       27.5             13.4
# 1059                       50.0             22.1
# ...                         ...              ...
# 72095                     580.3            263.3
# 72097                    1147.3            551.5
# 72099                     796.7            333.7
# 72101                     838.9            318.5
# 72103                     517.2            232.8
# 72105                    1109.5            411.7
# 72107                     368.2            145.5
# 72109                     412.8            200.4
# 72111                     544.2            206.6
# 72113                    1449.3            606.7
# 72115                    1142.7            474.1
# 72117                    1063.8            678.5
# 72119                     895.8            400.8
# 72121                     705.1            305.8
# 72123                     448.0            207.3
# 72125                     651.9            292.1
# 72127                    8262.3           4178.2
# 72129                     773.1            324.4
# 72131                     602.5            265.5
# 72133                     684.1            281.4
# 72135                    2741.5            999.6
# 72137                    3855.7           1572.5
# 72139                    3604.4           1459.0
# 72141                     292.0            125.0
# 72143                    1440.8            613.2
# 72145                    1301.1            553.9
# 72147                     183.2            109.1
# 72149                     731.6            272.5
# 72151                     687.2            286.1
# 72153                     616.5            264.3
#
# [3227 rows x 2 columns]

# %%
AQIDictionary[2000] = AQIDictionary[2000].set_index('County Code')
AQIDictionary[2000]
# Out:
#                                  County CO 2nd Max 8-hr NO2 Mean 1-hr  \
# County Code
# 1073               Jefferson County, AL            16.3           NaN
# 1089                 Madison County, AL             2.3           NaN
# 4013                Maricopa County, AZ             7.2            36
# 4019                    Pima County, AZ             4.7            17
# 5119                 Pulaski County, AR             2.9            10
# 6001                 Alameda County, CA               3            20
# 6007                   Butte County, CA             3.5            12
# 6009               Calaveras County, CA             0.8           NaN
# 6013            Contra Costa County, CA             2.6            16
# 6017               El Dorado County, CA             1.7            11
# 6019                  Fresno County, CA             5.9            21
# 6025                Imperial County, CA            14.4            19
# 6029                    Kern County, CA             5.2            24
# 6037             Los Angeles County, CA             9.9            44
# 6041                   Marin County, CA             2.1            16
# 6045               Mendocino County, CA             2.4            11
# 6053                Monterey County, CA             1.4             7
# 6055                    Napa County, CA             2.5            12
# 6059                  Orange County, CA               6            29
# 6061                  Placer County, CA               2            16
# 6065               Riverside County, CA             4.2            22
# 6067              Sacramento County, CA             6.2            19
# 6071          San Bernardino County, CA             3.7            38
# 6073               San Diego County, CA             4.7            24
# 6075           San Francisco County, CA             2.8            20
# 6077             San Joaquin County, CA             6.3            21
# 6079         San Luis Obispo County, CA             2.2            12
# 6081               San Mateo County, CA             3.6            18
# 6083           Santa Barbara County, CA               3            18
# 6085             Santa Clara County, CA             6.9            25
# ...                                 ...             ...           ...
# 48201                 Harris County, TX             4.2            21
# 48439                Tarrant County, TX             2.2            15
# 48453                 Travis County, TX             1.1             5
# 48479                   Webb County, TX             5.5           NaN
# 49011                  Davis County, UT             2.7            19
# 49035              Salt Lake County, UT             5.2            26
# 49049                   Utah County, UT               6            24
# 50007             Chittenden County, VT               2           NaN
# 50021                Rutland County, VT             2.5            11
# 51013              Arlington County, VA             2.7            23
# 51036                Charles County, VA             NaN            11
# 51059                Fairfax County, VA             3.5            21
# 51510               Alexandria City, VA             2.9            23
# 51650                  Hampton City, VA             2.4           NaN
# 51710                  Norfolk City, VA             4.1            16
# 53011                  Clark County, WA             6.2           NaN
# 53033                   King County, WA             6.3            21
# 53053                 Pierce County, WA             5.5           NaN
# 53063                Spokane County, WA             5.6           NaN
# 53067               Thurston County, WA             5.4           NaN
# 54009                 Brooke County, WV             5.3           NaN
# 54011                 Cabell County, WV             NaN           NaN
# 54029                Hancock County, WV             7.9           NaN
# 54061             Monongalia County, WV             NaN           NaN
# 54069                   Ohio County, WV             2.3           NaN
# 54107                   Wood County, WV             NaN           NaN
# 55025                   Dane County, WI             1.9           NaN
# 55079              Milwaukee County, WI             2.4            21
# 55133               Waukesha County, WI             2.4           NaN
# 72033              Catano Municipio, PR             NaN            18
#
#             Ozone 4th Max 8-hr SO2 2nd Max 24-hr PM2.5 Weighted Mean 24-hr  \
# County Code
# 1073                     0.094                57                      22.3
# 1089                     0.088               NaN                      16.3
# 4013                     0.087                12                      12.1
# 4019                     0.077                 7                       NaN
# 5119                     0.092                 7                      15.5
# 6001                     0.076               NaN                      11.2
# 6007                     0.078               NaN                      16.3
# 6009                     0.098               NaN                         9
# 6013                     0.077                21                      11.1
# 6017                     0.103               NaN                       7.8
# 6019                     0.114               NaN                      18.4
# 6025                     0.088               NaN                      16.9
# 6029                     0.111               NaN                      22.6
# 6037                     0.112                10                        24
# 6041                     0.045               NaN                       NaN
# 6045                     0.053               NaN                       NaN
# 6053                     0.066               NaN                       7.9
# 6055                     0.061               NaN                       NaN
# 6059                     0.083                 5                      14.7
# 6061                     0.092               NaN                      12.2
# 6065                     0.111               NaN                      28.3
# 6067                       0.1               NaN                      12.3
# 6071                     0.122                 6                      24.5
# 6073                     0.095                11                      15.8
# 6075                     0.041                 7                       NaN
# 6077                     0.082               NaN                      15.6
# 6079                      0.07                28                      10.3
# 6081                     0.048               NaN                       NaN
# 6083                      0.08                 3                       NaN
# 6085                     0.073               NaN                      13.6
# ...                        ...               ...                       ...
# 48201                    0.117                31                       NaN
# 48439                    0.095               NaN                      12.7
# 48453                    0.088               NaN                      12.1
# 48479                     0.07               NaN                      12.1
# 49011                    0.078                13                         9
# 49035                     0.08                13                      14.2
# 49049                    0.077               NaN                      10.1
# 50007                    0.069               NaN                       8.3
# 50021                      NaN                33                      11.1
# 51013                     0.08               NaN                      14.6
# 51036                    0.076                17                      13.6
# 51059                    0.092                30                        14
# 51510                    0.077                20                       NaN
# 51650                    0.081                17                       NaN
# 51710                      NaN                23                      13.6
# 53011                    0.058               NaN                      10.8
# 53033                     0.07               NaN                      12.8
# 53053                    0.064               NaN                        13
# 53063                    0.068               NaN                        11
# 53067                    0.055               NaN                      10.3
# 54009                      NaN                69                      16.5
# 54011                    0.081                28                      17.6
# 54029                    0.072                56                      17.7
# 54061                     0.08                40                        15
# 54069                    0.071                41                      15.3
# 54107                    0.087                36                      17.7
# 55025                    0.071               NaN                      12.8
# 55079                    0.083                26                      13.9
# 55133                    0.079               NaN                      13.4
# 72033                    0.047                27                       NaN
#
#             PM10 Mean 24-hr
# County Code
# 1073                     42
# 1089                     24
# 4013                     70
# 4019                     39
# 5119                     29
# 6001                     21
# 6007                     28
# 6009                     18
# 6013                     19
# 6017                     20
# 6019                     40
# 6025                    115
# 6029                     53
# 6037                     46
# 6041                     19
# 6045                     22
# 6053                     30
# 6055                     16
# 6059                     40
# 6061                     24
# 6065                     56
# 6067                     26
# 6071                     52
# 6073                     45
# 6075                     24
# 6077                     32
# 6079                     20
# 6081                     21
# 6083                     26
# 6085                     26
# ...                     ...
# 48201                    46
# 48439                    22
# 48453                    23
# 48479                    31
# 49011                   NaN
# 49035                    47
# 49049                    32
# 50007                    13
# 50021                    18
# 51013                   NaN
# 51036                   NaN
# 51059                    20
# 51510                   NaN
# 51650                    20
# 51710                    21
# 53011                    16
# 53033                    17
# 53053                    28
# 53063                    28
# 53067                    15
# 54009                    26
# 54011                    24
# 54029                    31
# 54061                    23
# 54069                    23
# 54107                    21
# 55025                    22
# 55079                    20
# 55133                    21
# 72033                    30
#
# [239 rows x 7 columns]

# %%
two_thou = pd.read_csv('Project/2000.csv')
two_thou = two_thou.drop(list(two_thou)[0], axis=1)
two_thou = two_thou.set_index('County Code')
two_thou
# Out:
#             MedianHouseholdIncome
# County Code
# 1001                        42463
# 1003                        41283
# 1005                        26612
# 1007                        31776
# 1009                        36863
# 1011                        21400
# 1013                        25763
# 1015                        32604
# 1017                        30505
# 1019                        31436
# 1021                        33650
# 1023                        26388
# 1025                        28734
# 1027                        28940
# 1029                        31551
# 1031                        34561
# 1033                        33227
# 1035                        23683
# 1037                        29926
# 1039                        27531
# 1041                        27345
# 1043                        33441
# 1045                        32824
# 1047                        24944
# 1049                        31087
# 1051                        41233
# 1053                        28942
# 1055                        31490
# 1057                        30362
# 1059                        28341
# ...                           ...
# 55129                       34585
# 55131                       59667
# 55133                       67047
# 55135                       42202
# 55137                       37430
# 55139                       46557
# 55141                       43793
# 56001                       32298
# 56003                       34478
# 56005                       53384
# 56007                       37910
# 56009                       41754
# 56011                       38130
# 56013                       34203
# 56015                       33155
# 56017                       31175
# 56019                       35921
# 56021                       41446
# 56023                       43455
# 56025                       38388
# 56027                       31720
# 56029                       37717
# 56031                       35899
# 56033                       36378
# 56035                       42463
# 56037                       50234
# 56039                       56447
# 56041                       45624
# 56043                       37322
# 56045                       35420
#
# [3139 rows x 1 columns]

# %%
merged = AQIDictionary[2000].merge(two_thou, left_index=True, right_index=True)
merged = merged.merge(pop_density, left_index=True, right_index=True)
merged
# Out:
#                                  County CO 2nd Max 8-hr NO2 Mean 1-hr  \
# County Code
# 1073               Jefferson County, AL            16.3           NaN
# 1089                 Madison County, AL             2.3           NaN
# 4013                Maricopa County, AZ             7.2            36
# 4019                    Pima County, AZ             4.7            17
# 5119                 Pulaski County, AR             2.9            10
# 6001                 Alameda County, CA               3            20
# 6007                   Butte County, CA             3.5            12
# 6009               Calaveras County, CA             0.8           NaN
# 6013            Contra Costa County, CA             2.6            16
# 6017               El Dorado County, CA             1.7            11
# 6019                  Fresno County, CA             5.9            21
# 6025                Imperial County, CA            14.4            19
# 6029                    Kern County, CA             5.2            24
# 6037             Los Angeles County, CA             9.9            44
# 6041                   Marin County, CA             2.1            16
# 6045               Mendocino County, CA             2.4            11
# 6053                Monterey County, CA             1.4             7
# 6055                    Napa County, CA             2.5            12
# 6059                  Orange County, CA               6            29
# 6061                  Placer County, CA               2            16
# 6065               Riverside County, CA             4.2            22
# 6067              Sacramento County, CA             6.2            19
# 6071          San Bernardino County, CA             3.7            38
# 6073               San Diego County, CA             4.7            24
# 6075           San Francisco County, CA             2.8            20
# 6077             San Joaquin County, CA             6.3            21
# 6079         San Luis Obispo County, CA             2.2            12
# 6081               San Mateo County, CA             3.6            18
# 6083           Santa Barbara County, CA               3            18
# 6085             Santa Clara County, CA             6.9            25
# ...                                 ...             ...           ...
# 48183                  Gregg County, TX             NaN             6
# 48201                 Harris County, TX             4.2            21
# 48439                Tarrant County, TX             2.2            15
# 48453                 Travis County, TX             1.1             5
# 48479                   Webb County, TX             5.5           NaN
# 49011                  Davis County, UT             2.7            19
# 49035              Salt Lake County, UT             5.2            26
# 49049                   Utah County, UT               6            24
# 50007             Chittenden County, VT               2           NaN
# 50021                Rutland County, VT             2.5            11
# 51013              Arlington County, VA             2.7            23
# 51036                Charles County, VA             NaN            11
# 51059                Fairfax County, VA             3.5            21
# 51510               Alexandria City, VA             2.9            23
# 51650                  Hampton City, VA             2.4           NaN
# 51710                  Norfolk City, VA             4.1            16
# 53011                  Clark County, WA             6.2           NaN
# 53033                   King County, WA             6.3            21
# 53053                 Pierce County, WA             5.5           NaN
# 53063                Spokane County, WA             5.6           NaN
# 53067               Thurston County, WA             5.4           NaN
# 54009                 Brooke County, WV             5.3           NaN
# 54011                 Cabell County, WV             NaN           NaN
# 54029                Hancock County, WV             7.9           NaN
# 54061             Monongalia County, WV             NaN           NaN
# 54069                   Ohio County, WV             2.3           NaN
# 54107                   Wood County, WV             NaN           NaN
# 55025                   Dane County, WI             1.9           NaN
# 55079              Milwaukee County, WI             2.4            21
# 55133               Waukesha County, WI             2.4           NaN
#
#             Ozone 4th Max 8-hr SO2 2nd Max 24-hr PM2.5 Weighted Mean 24-hr  \
# County Code
# 1073                     0.094                57                      22.3
# 1089                     0.088               NaN                      16.3
# 4013                     0.087                12                      12.1
# 4019                     0.077                 7                       NaN
# 5119                     0.092                 7                      15.5
# 6001                     0.076               NaN                      11.2
# 6007                     0.078               NaN                      16.3
# 6009                     0.098               NaN                         9
# 6013                     0.077                21                      11.1
# 6017                     0.103               NaN                       7.8
# 6019                     0.114               NaN                      18.4
# 6025                     0.088               NaN                      16.9
# 6029                     0.111               NaN                      22.6
# 6037                     0.112                10                        24
# 6041                     0.045               NaN                       NaN
# 6045                     0.053               NaN                       NaN
# 6053                     0.066               NaN                       7.9
# 6055                     0.061               NaN                       NaN
# 6059                     0.083                 5                      14.7
# 6061                     0.092               NaN                      12.2
# 6065                     0.111               NaN                      28.3
# 6067                       0.1               NaN                      12.3
# 6071                     0.122                 6                      24.5
# 6073                     0.095                11                      15.8
# 6075                     0.041                 7                       NaN
# 6077                     0.082               NaN                      15.6
# 6079                      0.07                28                      10.3
# 6081                     0.048               NaN                       NaN
# 6083                      0.08                 3                       NaN
# 6085                     0.073               NaN                      13.6
# ...                        ...               ...                       ...
# 48183                    0.099                11                      13.4
# 48201                    0.117                31                       NaN
# 48439                    0.095               NaN                      12.7
# 48453                    0.088               NaN                      12.1
# 48479                     0.07               NaN                      12.1
# 49011                    0.078                13                         9
# 49035                     0.08                13                      14.2
# 49049                    0.077               NaN                      10.1
# 50007                    0.069               NaN                       8.3
# 50021                      NaN                33                      11.1
# 51013                     0.08               NaN                      14.6
# 51036                    0.076                17                      13.6
# 51059                    0.092                30                        14
# 51510                    0.077                20                       NaN
# 51650                    0.081                17                       NaN
# 51710                      NaN                23                      13.6
# 53011                    0.058               NaN                      10.8
# 53033                     0.07               NaN                      12.8
# 53053                    0.064               NaN                        13
# 53063                    0.068               NaN                        11
# 53067                    0.055               NaN                      10.3
# 54009                      NaN                69                      16.5
# 54011                    0.081                28                      17.6
# 54029                    0.072                56                      17.7
# 54061                     0.08                40                        15
# 54069                    0.071                41                      15.3
# 54107                    0.087                36                      17.7
# 55025                    0.071               NaN                      12.8
# 55079                    0.083                26                      13.9
# 55133                    0.079               NaN                      13.4
#
#             PM10 Mean 24-hr MedianHouseholdIncome  Population Density  \
# County Code
# 1073                     42                 37094               592.5
# 1089                     24                 45736               417.7
# 4013                     70                 47024               414.9
# 4019                     39                 37461               106.7
# 5119                     29                 38328               503.8
# 6001                     21                 55551              2043.6
# 6007                     28                 31963               134.4
# 6009                     18                 41460                44.7
# 6013                     19                 64040              1465.2
# 6017                     20                 52155               106.0
# 6019                     40                 34930               156.2
# 6025                    115                 31651                41.8
# 6029                     53                 36446               103.3
# 6037                     46                 42045              2419.6
# 6041                     19                 72301               485.1
# 6045                     22                 36240                25.1
# 6053                     30                 47073               126.5
# 6055                     16                 52262               182.4
# 6059                     40                 55654              3807.7
# 6061                     24                 59153               247.6
# 6065                     56                 43558               303.8
# 6067                     26                 44796              1470.8
# 6071                     52                 40950               101.5
# 6073                     45                 48363               735.8
# 6075                     24                 55761             17179.2
# 6077                     32                 40633               492.6
# 6079                     20                 42498                81.7
# 6081                     21                 70492              1602.2
# 6083                     26                 46908               155.0
# 6085                     26                 74705              1381.0
# ...                     ...                   ...                 ...
# 48183                   NaN                 36039               445.4
# 48201                    46                 41220              2402.4
# 48439                    22                 48473              2094.7
# 48453                    23                 48406              1034.4
# 48479                    31                 28245                74.5
# 49011                   NaN                 55115              1025.8
# 49035                    47                 48688              1387.1
# 49049                    32                 47499               257.8
# 50007                    13                 49733               291.7
# 50021                    18                 37160                66.3
# 51013                   NaN                 65881              7993.5
# 51036                   NaN                 42355                39.7
# 51059                    20                 84009              2766.8
# 51510                   NaN                 57620              9314.3
# 51650                    20                 39392              2673.2
# 51710                    21                 30863              4486.3
# 53011                    16                 49569               676.2
# 53033                    17                 55158               912.9
# 53053                    28                 46222               476.3
# 53063                    28                 38172               267.2
# 53067                    15                 48347               349.4
# 54009                    26                 33483               269.8
# 54011                    24                 29639               342.8
# 54029                    31                 35017               371.3
# 54061                    23                 31215               267.1
# 54069                    23                 32915               420.0
# 54107                    21                 34736               237.4
# 55025                    22                 51150               407.7
# 55079                    20                 39593              3926.0
# 55133                    21                 67047               709.4
#
#              Housing Density
# County Code
# 1073                   270.5
# 1089                   182.7
# 4013                   178.2
# 4019                    48.0
# 5119                   231.1
# 6001                   788.3
# 6007                    58.6
# 6009                    27.4
# 6013                   559.1
# 6017                    51.6
# 6019                    53.0
# 6025                    13.4
# 6029                    35.0
# 6037                   849.0
# 6041                   213.7
# 6045                    11.5
# 6053                    42.4
# 6055                    73.2
# 6059                  1326.8
# 6061                   108.5
# 6065                   111.1
# 6067                   576.3
# 6071                    34.9
# 6073                   276.9
# 6075                  8041.8
# 6077                   168.0
# 6079                    35.6
# 6081                   604.4
# 6083                    55.9
# 6085                   489.8
# ...                      ...
# 48183                  181.2
# 48201                  938.5
# 48439                  827.7
# 48453                  445.6
# 48479                   21.9
# 49011                  326.6
# 49035                  490.4
# 49049                   74.0
# 50007                  122.5
# 50021                   36.3
# 51013                 4058.0
# 51036                   17.7
# 51059                 1043.6
# 51510                 4816.4
# 51650                 1158.6
# 51710                 1755.7
# 53011                  266.2
# 53033                  402.4
# 53053                  194.9
# 53063                  114.2
# 53067                  149.8
# 54009                  122.9
# 54011                  164.3
# 54029                  176.0
# 54061                  120.1
# 54069                  200.1
# 54107                  109.8
# 55025                  180.4
# 55079                 1731.8
# 55133                  292.7
#
# [237 rows x 10 columns]

# %%
almost = pd.DataFrame()
for year in YEARS:
    almost = almost.append(concatnated[year])

# %%
data = merged.drop('County', axis=1)
#values = {'CO 2nd Max 8-hr':3.2, 'NO2 Mean 1-hr':0, 'Ozone 4th Max 8-hr':0, 'SO2 2nd Max 24-hr':0, 'PM2.5 Weighted Mean 24-hr':0, 'PM10 Mean 24-hr':0}
values = {'CO 2nd Max 8-hr':3.2, 'NO2 Mean 1-hr':17, 'Ozone 4th Max 8-hr':0.081, 'SO2 2nd Max 24-hr':22, 'PM2.5 Weighted Mean 24-hr':13.85, 'PM10 Mean 24-hr':26}
data = data.fillna(value=values)
data
# Out:
#             CO 2nd Max 8-hr NO2 Mean 1-hr Ozone 4th Max 8-hr  \
# County Code
# 1073                   16.3            17              0.094
# 1089                    2.3            17              0.088
# 4013                    7.2            36              0.087
# 4019                    4.7            17              0.077
# 5119                    2.9            10              0.092
# 6001                      3            20              0.076
# 6007                    3.5            12              0.078
# 6009                    0.8            17              0.098
# 6013                    2.6            16              0.077
# 6017                    1.7            11              0.103
# 6019                    5.9            21              0.114
# 6025                   14.4            19              0.088
# 6029                    5.2            24              0.111
# 6037                    9.9            44              0.112
# 6041                    2.1            16              0.045
# 6045                    2.4            11              0.053
# 6053                    1.4             7              0.066
# 6055                    2.5            12              0.061
# 6059                      6            29              0.083
# 6061                      2            16              0.092
# 6065                    4.2            22              0.111
# 6067                    6.2            19                0.1
# 6071                    3.7            38              0.122
# 6073                    4.7            24              0.095
# 6075                    2.8            20              0.041
# 6077                    6.3            21              0.082
# 6079                    2.2            12               0.07
# 6081                    3.6            18              0.048
# 6083                      3            18               0.08
# 6085                    6.9            25              0.073
# ...                     ...           ...                ...
# 48183                   3.2             6              0.099
# 48201                   4.2            21              0.117
# 48439                   2.2            15              0.095
# 48453                   1.1             5              0.088
# 48479                   5.5            17               0.07
# 49011                   2.7            19              0.078
# 49035                   5.2            26               0.08
# 49049                     6            24              0.077
# 50007                     2            17              0.069
# 50021                   2.5            11              0.081
# 51013                   2.7            23               0.08
# 51036                   3.2            11              0.076
# 51059                   3.5            21              0.092
# 51510                   2.9            23              0.077
# 51650                   2.4            17              0.081
# 51710                   4.1            16              0.081
# 53011                   6.2            17              0.058
# 53033                   6.3            21               0.07
# 53053                   5.5            17              0.064
# 53063                   5.6            17              0.068
# 53067                   5.4            17              0.055
# 54009                   5.3            17              0.081
# 54011                   3.2            17              0.081
# 54029                   7.9            17              0.072
# 54061                   3.2            17               0.08
# 54069                   2.3            17              0.071
# 54107                   3.2            17              0.087
# 55025                   1.9            17              0.071
# 55079                   2.4            21              0.083
# 55133                   2.4            17              0.079
#
#             SO2 2nd Max 24-hr PM2.5 Weighted Mean 24-hr PM10 Mean 24-hr  \
# County Code
# 1073                       57                      22.3              42
# 1089                       22                      16.3              24
# 4013                       12                      12.1              70
# 4019                        7                     13.85              39
# 5119                        7                      15.5              29
# 6001                       22                      11.2              21
# 6007                       22                      16.3              28
# 6009                       22                         9              18
# 6013                       21                      11.1              19
# 6017                       22                       7.8              20
# 6019                       22                      18.4              40
# 6025                       22                      16.9             115
# 6029                       22                      22.6              53
# 6037                       10                        24              46
# 6041                       22                     13.85              19
# 6045                       22                     13.85              22
# 6053                       22                       7.9              30
# 6055                       22                     13.85              16
# 6059                        5                      14.7              40
# 6061                       22                      12.2              24
# 6065                       22                      28.3              56
# 6067                       22                      12.3              26
# 6071                        6                      24.5              52
# 6073                       11                      15.8              45
# 6075                        7                     13.85              24
# 6077                       22                      15.6              32
# 6079                       28                      10.3              20
# 6081                       22                     13.85              21
# 6083                        3                     13.85              26
# 6085                       22                      13.6              26
# ...                       ...                       ...             ...
# 48183                      11                      13.4              26
# 48201                      31                     13.85              46
# 48439                      22                      12.7              22
# 48453                      22                      12.1              23
# 48479                      22                      12.1              31
# 49011                      13                         9              26
# 49035                      13                      14.2              47
# 49049                      22                      10.1              32
# 50007                      22                       8.3              13
# 50021                      33                      11.1              18
# 51013                      22                      14.6              26
# 51036                      17                      13.6              26
# 51059                      30                        14              20
# 51510                      20                     13.85              26
# 51650                      17                     13.85              20
# 51710                      23                      13.6              21
# 53011                      22                      10.8              16
# 53033                      22                      12.8              17
# 53053                      22                        13              28
# 53063                      22                        11              28
# 53067                      22                      10.3              15
# 54009                      69                      16.5              26
# 54011                      28                      17.6              24
# 54029                      56                      17.7              31
# 54061                      40                        15              23
# 54069                      41                      15.3              23
# 54107                      36                      17.7              21
# 55025                      22                      12.8              22
# 55079                      26                      13.9              20
# 55133                      22                      13.4              21
#
#             MedianHouseholdIncome  Population Density  Housing Density
# County Code
# 1073                        37094               592.5            270.5
# 1089                        45736               417.7            182.7
# 4013                        47024               414.9            178.2
# 4019                        37461               106.7             48.0
# 5119                        38328               503.8            231.1
# 6001                        55551              2043.6            788.3
# 6007                        31963               134.4             58.6
# 6009                        41460                44.7             27.4
# 6013                        64040              1465.2            559.1
# 6017                        52155               106.0             51.6
# 6019                        34930               156.2             53.0
# 6025                        31651                41.8             13.4
# 6029                        36446               103.3             35.0
# 6037                        42045              2419.6            849.0
# 6041                        72301               485.1            213.7
# 6045                        36240                25.1             11.5
# 6053                        47073               126.5             42.4
# 6055                        52262               182.4             73.2
# 6059                        55654              3807.7           1326.8
# 6061                        59153               247.6            108.5
# 6065                        43558               303.8            111.1
# 6067                        44796              1470.8            576.3
# 6071                        40950               101.5             34.9
# 6073                        48363               735.8            276.9
# 6075                        55761             17179.2           8041.8
# 6077                        40633               492.6            168.0
# 6079                        42498                81.7             35.6
# 6081                        70492              1602.2            604.4
# 6083                        46908               155.0             55.9
# 6085                        74705              1381.0            489.8
# ...                           ...                 ...              ...
# 48183                       36039               445.4            181.2
# 48201                       41220              2402.4            938.5
# 48439                       48473              2094.7            827.7
# 48453                       48406              1034.4            445.6
# 48479                       28245                74.5             21.9
# 49011                       55115              1025.8            326.6
# 49035                       48688              1387.1            490.4
# 49049                       47499               257.8             74.0
# 50007                       49733               291.7            122.5
# 50021                       37160                66.3             36.3
# 51013                       65881              7993.5           4058.0
# 51036                       42355                39.7             17.7
# 51059                       84009              2766.8           1043.6
# 51510                       57620              9314.3           4816.4
# 51650                       39392              2673.2           1158.6
# 51710                       30863              4486.3           1755.7
# 53011                       49569               676.2            266.2
# 53033                       55158               912.9            402.4
# 53053                       46222               476.3            194.9
# 53063                       38172               267.2            114.2
# 53067                       48347               349.4            149.8
# 54009                       33483               269.8            122.9
# 54011                       29639               342.8            164.3
# 54029                       35017               371.3            176.0
# 54061                       31215               267.1            120.1
# 54069                       32915               420.0            200.1
# 54107                       34736               237.4            109.8
# 55025                       51150               407.7            180.4
# 55079                       39593              3926.0           1731.8
# 55133                       67047               709.4            292.7
#
# [237 rows x 9 columns]

# %%
import scipy.stats as stats
import matplotlib.pyplot as plt
import sklearn
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
X = data.drop('MedianHouseholdIncome', axis = 1)
lm = LinearRegression()
lm.fit(X, data.MedianHouseholdIncome)
coeff = pd.DataFrame(zip(X.columns, lm.coef_), columns = {'features', 'estimatedCoefficients'})
coeff
# Out:
#                     features  estimatedCoefficients
# 0            CO 2nd Max 8-hr            -185.034725
# 1              NO2 Mean 1-hr             383.042317
# 2         Ozone 4th Max 8-hr          -27471.719624
# 3          SO2 2nd Max 24-hr            -106.341578
# 4  PM2.5 Weighted Mean 24-hr            -293.708048
# 5            PM10 Mean 24-hr            -176.804306
# 6         Population Density              -0.481472
# 7            Housing Density               0.755471

# %%
X_train, X_test, Y_train, Y_test = train_test_split(
    X, data.MedianHouseholdIncome, test_size = 0.33, random_state = 5)
print X_train.shape
print X_test.shape
print Y_train.shape
print Y_test.shape
# Out:
# (158, 8)
# (79, 8)
# (158L,)
# (79L,)

# %%
lm = LinearRegression()
lm.fit(X_train, Y_train)
pred_train = lm.predict(X_train)
pred_test = lm.predict(X_test)


Y_train = Y_train.values.astype(float)
Y_test = Y_test.values.astype(float)

print('Fit a model X_train, and calculate MSE with Y_train: ', np.mean((Y_train - lm.predict(X_train)) ** 2))

print('Fit a model X_train, and calculate MSE with X_test, Y_test: ', np.mean((Y_test - lm.predict(X_test)) ** 2))
# Out:
# ('Fit a model X_train, and calculate MSE with Y_train: ', 93664257.93263237)
# ('Fit a model X_train, and calculate MSE with X_test, Y_test: ', 76036269.66625838)

# %%
Baselines
- random guessing
- majority classfier
- logistic regression - sklearn
- 1 layer neural network 

Oracle
- cheating
- literature (paper with same data)
- derive weakly linked relationship

Proposal
- why is this proble interesting
- Have you thought about it more
- How

# %%
import sklearn
import numpy as np
import seaborn as sns
# Out:
#      County Code                      County CO 2nd Max 8-hr NO2 Mean 1-hr  \
# 9           1073        Jefferson County, AL            16.3           NaN
# 11          1089          Madison County, AL             2.3           NaN
# 29          4013         Maricopa County, AZ             7.2            36
# 31          4019             Pima County, AZ             4.7            17
# 43          5119          Pulaski County, AR             2.9            10
# 46          6001          Alameda County, CA               3            20
# 48          6007            Butte County, CA             3.5            12
# 49          6009        Calaveras County, CA             0.8           NaN
# 51          6013     Contra Costa County, CA             2.6            16
# 52          6017        El Dorado County, CA             1.7            11
# 53          6019           Fresno County, CA             5.9            21
# 56          6025         Imperial County, CA            14.4            19
# 58          6029             Kern County, CA             5.2            24
# 61          6037      Los Angeles County, CA             9.9            44
# 63          6041            Marin County, CA             2.1            16
# 65          6045        Mendocino County, CA             2.4            11
# 69          6053         Monterey County, CA             1.4             7
# 70          6055             Napa County, CA             2.5            12
# 72          6059           Orange County, CA               6            29
# 73          6061           Placer County, CA               2            16
# 75          6065        Riverside County, CA             4.2            22
# 76          6067       Sacramento County, CA             6.2            19
# 78          6071   San Bernardino County, CA             3.7            38
# 79          6073        San Diego County, CA             4.7            24
# 80          6075    San Francisco County, CA             2.8            20
# 81          6077      San Joaquin County, CA             6.3            21
# 82          6079  San Luis Obispo County, CA             2.2            12
# 83          6081        San Mateo County, CA             3.6            18
# 84          6083    Santa Barbara County, CA               3            18
# 85          6085      Santa Clara County, CA             6.9            25
# ..           ...                         ...             ...           ...
# 797        48201           Harris County, TX             4.2            21
# 805        48439          Tarrant County, TX             2.2            15
# 806        48453           Travis County, TX             1.1             5
# 808        48479             Webb County, TX             5.5           NaN
# 810        49011            Davis County, UT             2.7            19
# 812        49035        Salt Lake County, UT             5.2            26
# 815        49049             Utah County, UT               6            24
# 818        50007       Chittenden County, VT               2           NaN
# 819        50021          Rutland County, VT             2.5            11
# 821        51013        Arlington County, VA             2.7            23
# 824        51036          Charles County, VA             NaN            11
# 827        51059          Fairfax County, VA             3.5            21
# 843        51510         Alexandria City, VA             2.9            23
# 848        51650            Hampton City, VA             2.4           NaN
# 850        51710            Norfolk City, VA             4.1            16
# 861        53011            Clark County, WA             6.2           NaN
# 864        53033             King County, WA             6.3            21
# 867        53053           Pierce County, WA             5.5           NaN
# 870        53063          Spokane County, WA             5.6           NaN
# 872        53067         Thurston County, WA             5.4           NaN
# 878        54009           Brooke County, WV             5.3           NaN
# 879        54011           Cabell County, WV             NaN           NaN
# 881        54029          Hancock County, WV             7.9           NaN
# 887        54061       Monongalia County, WV             NaN           NaN
# 888        54069             Ohio County, WV             2.3           NaN
# 892        54107             Wood County, WV             NaN           NaN
# 895        55025             Dane County, WI             1.9           NaN
# 906        55079        Milwaukee County, WI             2.4            21
# 919        55133         Waukesha County, WI             2.4           NaN
# 936        72033        Catano Municipio, PR             NaN            18
#
#     Ozone 4th Max 8-hr SO2 2nd Max 24-hr PM2.5 Weighted Mean 24-hr  \
# 9                0.094                57                      22.3
# 11               0.088               NaN                      16.3
# 29               0.087                12                      12.1
# 31               0.077                 7                       NaN
# 43               0.092                 7                      15.5
# 46               0.076               NaN                      11.2
# 48               0.078               NaN                      16.3
# 49               0.098               NaN                         9
# 51               0.077                21                      11.1
# 52               0.103               NaN                       7.8
# 53               0.114               NaN                      18.4
# 56               0.088               NaN                      16.9
# 58               0.111               NaN                      22.6
# 61               0.112                10                        24
# 63               0.045               NaN                       NaN
# 65               0.053               NaN                       NaN
# 69               0.066               NaN                       7.9
# 70               0.061               NaN                       NaN
# 72               0.083                 5                      14.7
# 73               0.092               NaN                      12.2
# 75               0.111               NaN                      28.3
# 76                 0.1               NaN                      12.3
# 78               0.122                 6                      24.5
# 79               0.095                11                      15.8
# 80               0.041                 7                       NaN
# 81               0.082               NaN                      15.6
# 82                0.07                28                      10.3
# 83               0.048               NaN                       NaN
# 84                0.08                 3                       NaN
# 85               0.073               NaN                      13.6
# ..                 ...               ...                       ...
# 797              0.117                31                       NaN
# 805              0.095               NaN                      12.7
# 806              0.088               NaN                      12.1
# 808               0.07               NaN                      12.1
# 810              0.078                13                         9
# 812               0.08                13                      14.2
# 815              0.077               NaN                      10.1
# 818              0.069               NaN                       8.3
# 819                NaN                33                      11.1
# 821               0.08               NaN                      14.6
# 824              0.076                17                      13.6
# 827              0.092                30                        14
# 843              0.077                20                       NaN
# 848              0.081                17                       NaN
# 850                NaN                23                      13.6
# 861              0.058               NaN                      10.8
# 864               0.07               NaN                      12.8
# 867              0.064               NaN                        13
# 870              0.068               NaN                        11
# 872              0.055               NaN                      10.3
# 878                NaN                69                      16.5
# 879              0.081                28                      17.6
# 881              0.072                56                      17.7
# 887               0.08                40                        15
# 888              0.071                41                      15.3
# 892              0.087                36                      17.7
# 895              0.071               NaN                      12.8
# 906              0.083                26                      13.9
# 919              0.079               NaN                      13.4
# 936              0.047                27                       NaN
#
#     PM10 Mean 24-hr
# 9                42
# 11               24
# 29               70
# 31               39
# 43               29
# 46               21
# 48               28
# 49               18
# 51               19
# 52               20
# 53               40
# 56              115
# 58               53
# 61               46
# 63               19
# 65               22
# 69               30
# 70               16
# 72               40
# 73               24
# 75               56
# 76               26
# 78               52
# 79               45
# 80               24
# 81               32
# 82               20
# 83               21
# 84               26
# 85               26
# ..              ...
# 797              46
# 805              22
# 806              23
# 808              31
# 810             NaN
# 812              47
# 815              32
# 818              13
# 819              18
# 821             NaN
# 824             NaN
# 827              20
# 843             NaN
# 848              20
# 850              21
# 861              16
# 864              17
# 867              28
# 870              28
# 872              15
# 878              26
# 879              24
# 881              31
# 887              23
# 888              23
# 892              21
# 895              22
# 906              20
# 919              21
# 936              30
#
# [239 rows x 8 columns]
